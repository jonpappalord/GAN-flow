# %%
import numpy as np
import math
import pandas as pd
import itertools
from random import sample
import pickle
from scipy.spatial import distance

import seaborn as sns

# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import FormatStrFormatter
from matplotlib.offsetbox import AnchoredText
plt.rcParams["figure.figsize"] = (18, 15) # (w, h)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Radiation #

# %%
with open("BikeNYC/experiments/weight/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/weight/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/weight/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_bike = pickle.load(fp)    
    
with open("TaxiNYC/experiments/weight/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/weight/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/weight/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_taxi = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/weight/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/weight/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/weight/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_bike = pickle.load(fp)    
    
with open("TaxiCHI/experiments/weight/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/weight/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/weight/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_taxi = pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############
    
with open("BikeNYC/experiments/weightdist/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/weightdist/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/weightdist/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_bike = pickle.load(fp)    
    
with open("TaxiNYC/experiments/weightdist/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/weightdist/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/weightdist/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_taxi = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/weightdist/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/weightdist/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/weightdist/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_bike = pickle.load(fp)    
    
with open("TaxiCHI/experiments/weightdist/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/weightdist/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/weightdist/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_taxi = pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############    

with open("BikeNYC/experiments/cutnorm/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/cutnorm/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/cutnorm/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_bike = pickle.load(fp)    
    
with open("TaxiNYC/experiments/cutnorm/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/cutnorm/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/cutnorm/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_taxi = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/cutnorm/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/cutnorm/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/cutnorm/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_bike = pickle.load(fp)    
    
with open("TaxiCHI/experiments/cutnorm/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/cutnorm/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/cutnorm/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_taxi = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("BikeNYC/experiments/cpc/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/cpc/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/cpc/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_bike = pickle.load(fp)    
    
with open("TaxiNYC/experiments/cpc/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/cpc/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/cpc/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_taxi = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/cpc/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/cpc/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/cpc/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_bike = pickle.load(fp)    
    
with open("TaxiCHI/experiments/cpc/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/cpc/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/cpc/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_taxi = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("BikeNYC/experiments/rmse/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/rmse/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/rmse/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_bike = pickle.load(fp)    
    
with open("TaxiNYC/experiments/rmse/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/rmse/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/rmse/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_taxi = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/rmse/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/rmse/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/rmse/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_bike = pickle.load(fp)    
    
with open("TaxiCHI/experiments/rmse/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/rmse/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/rmse/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_taxi = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############    


with open("BikeNYC/experiments/kernel/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/kernel/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_bike = pickle.load(fp)
with open("BikeNYC/experiments/kernel/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_bike = pickle.load(fp)    
    
with open("TaxiNYC/experiments/kernel/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/kernel/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_taxi = pickle.load(fp)
with open("TaxiNYC/experiments/kernel/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_taxi = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/kernel/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/kernel/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_bike = pickle.load(fp)
with open("BikeCHI/experiments/kernel/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_bike = pickle.load(fp)    
    
with open("TaxiCHI/experiments/kernel/Radiation/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/kernel/Radiation/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_taxi = pickle.load(fp)
with open("TaxiCHI/experiments/kernel/Radiation/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_taxi = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############

# %% [markdown]
# # Gravity #

# %%
with open("BikeNYC/experiments/weight/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/weight/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/weight/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_bike_gravity = pickle.load(fp)    
    
with open("TaxiNYC/experiments/weight/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/weight/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/weight/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_taxi_gravity = pickle.load(fp)   
        
with open("BikeCHI/experiments/weight/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/weight/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/weight/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_bike_gravity = pickle.load(fp)    
    
with open("TaxiCHI/experiments/weight/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/weight/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/weight/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_taxi_gravity = pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############
    
with open("BikeNYC/experiments/weightdist/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/weightdist/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/weightdist/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_bike_gravity = pickle.load(fp)    
    
with open("TaxiNYC/experiments/weightdist/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/weightdist/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/weightdist/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_taxi_gravity = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/weightdist/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/weightdist/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/weightdist/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_bike_gravity = pickle.load(fp)    
    
with open("TaxiCHI/experiments/weightdist/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/weightdist/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/weightdist/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_taxi_gravity = pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############    

with open("BikeNYC/experiments/cutnorm/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/cutnorm/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/cutnorm/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_bike_gravity = pickle.load(fp)    
    
with open("TaxiNYC/experiments/cutnorm/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/cutnorm/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/cutnorm/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_taxi_gravity = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/cutnorm/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/cutnorm/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/cutnorm/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_bike_gravity = pickle.load(fp)    
    
with open("TaxiCHI/experiments/cutnorm/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/cutnorm/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/cutnorm/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_taxi_gravity = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("BikeNYC/experiments/cpc/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/cpc/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/cpc/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_bike_gravity = pickle.load(fp)    
    
with open("TaxiNYC/experiments/cpc/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/cpc/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/cpc/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_taxi_gravity = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/cpc/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/cpc/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/cpc/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_bike_gravity = pickle.load(fp)    
    
with open("TaxiCHI/experiments/cpc/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/cpc/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/cpc/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_taxi_gravity = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("BikeNYC/experiments/rmse/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/rmse/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/rmse/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_bike_gravity = pickle.load(fp)    
    
with open("TaxiNYC/experiments/rmse/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/rmse/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/rmse/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_taxi_gravity = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/rmse/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/rmse/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/rmse/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_bike_gravity = pickle.load(fp)    
    
with open("TaxiCHI/experiments/rmse/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/rmse/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/rmse/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_taxi_gravity = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("BikeNYC/experiments/kernel/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/kernel/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_bike_gravity = pickle.load(fp)
with open("BikeNYC/experiments/kernel/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_bike_gravity = pickle.load(fp)    
    
with open("TaxiNYC/experiments/kernel/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/kernel/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_taxi_gravity = pickle.load(fp)
with open("TaxiNYC/experiments/kernel/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_taxi_gravity = pickle.load(fp)   
    
    
with open("BikeCHI/experiments/kernel/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/kernel/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_bike_gravity = pickle.load(fp)
with open("BikeCHI/experiments/kernel/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_bike_gravity = pickle.load(fp)    
    
with open("TaxiCHI/experiments/kernel/Gravity/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/kernel/Gravity/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_taxi_gravity = pickle.load(fp)
with open("TaxiCHI/experiments/kernel/Gravity/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_taxi_gravity = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############

# %% [markdown]
# # MoGAN #

# %%
with open("BikeNYC/experiments/weight/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/weight/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/weight/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiNYC/experiments/weight/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/weight/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/weight/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("BikeCHI/experiments/weight/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/weight/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/weight/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiCHI/experiments/weight/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/weight/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/weight/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_taxi_MoGAN= pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############
    
with open("BikeNYC/experiments/weightdist/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/weightdist/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/weightdist/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiNYC/experiments/weightdist/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/weightdist/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/weightdist/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("BikeCHI/experiments/weightdist/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/weightdist/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/weightdist/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiCHI/experiments/weightdist/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/weightdist/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/weightdist/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_taxi_MoGAN= pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############    

with open("BikeNYC/experiments/cutnorm/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/cutnorm/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/cutnorm/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiNYC/experiments/cutnorm/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/cutnorm/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/cutnorm/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("BikeCHI/experiments/cutnorm/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/cutnorm/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/cutnorm/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiCHI/experiments/cutnorm/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/cutnorm/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/cutnorm/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("BikeNYC/experiments/cpc/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/cpc/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/cpc/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiNYC/experiments/cpc/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/cpc/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/cpc/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("BikeCHI/experiments/cpc/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/cpc/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/cpc/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiCHI/experiments/cpc/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/cpc/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/cpc/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("BikeNYC/experiments/rmse/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/rmse/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/rmse/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiNYC/experiments/rmse/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/rmse/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/rmse/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("BikeCHI/experiments/rmse/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/rmse/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/rmse/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiCHI/experiments/rmse/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/rmse/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/rmse/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############    

with open("BikeNYC/experiments/kernel/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/kernel/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("BikeNYC/experiments/kernel/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiNYC/experiments/kernel/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/kernel/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("TaxiNYC/experiments/kernel/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("BikeCHI/experiments/kernel/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/kernel/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("BikeCHI/experiments/kernel/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("TaxiCHI/experiments/kernel/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/kernel/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("TaxiCHI/experiments/kernel/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############

# %%
def plot_JS_hist(exp1, exp2, exp3, ax, measure, metric, ylabel = False):   
    
    if isinstance(exp1, np.ndarray):
        exp1 =  exp1.tolist()
    if isinstance(exp2, np.ndarray):
        exp2 =  exp2.tolist()
    
    kwargs = dict(histtype='stepfilled', ec="k",  facecolor='none', density = True)
    
    min_v = min (exp1+exp2+exp3)
    max_v = max (exp1+exp2+exp3)
    
    r = np.linspace(min_v,max_v,20)
    k, bins = np.histogram(r,20)
    
    #bins = 20
    sns.kdeplot(exp1, label = "Test", bw_method=0.5, ax=ax, color = "red",   linewidth=1)
    sns.kdeplot(exp2, label = "Synthetic", bw_method=0.5, ax=ax, color = "blue",  linewidth=1)
    sns.kdeplot(exp3, label = "Mixed", bw_method=0.5, ax=ax, color = "green", linewidth=3)
    
    #INTER-DISTRIBUTION js
    values_3, base_3 = np.histogram(exp3, bins=bins, density=1)
    values_1, base_1 = np.histogram(exp1, bins=bins, density=1)
    js1 = distance.jensenshannon(np.asarray(values_3), np.asarray(values_1), np.e)
    
    values_2, base_2 = np.histogram(exp2, bins=bins, density=1)
    js2 = distance.jensenshannon(np.asarray(values_2), np.asarray(values_1), np.e)

    #text1 = str("JS(m,t)=%.2f" % js1)
    #text2 = str("JS(s,t)=%.2f" % js2)
    #text = text1 + '\n' + text2
    
    #ax.annotate(text, xy=(0.451, 0.99), xycoords='axes fraction', fontsize = 32, style = 'italic')    
    
    ax.tick_params(labelsize=34)
    ax.set_xlabel(measure, fontsize = 34)
    
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    if ylabel:
        ax.set_ylabel("density", fontsize = 34)
    else:
        ax.set_ylabel("", fontsize = 34)

    
    return (js1, js2)
    #ax.legend( prop={'size': 18})

# %% [markdown]
# ## Weights ##

# %%
f, axs = plt.subplots(2, 11, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,0.01,22,   8,  22,0.01,22, 0.01, 22], hspace=0.4, wspace = 0.2))

axs[0,2].sharey(axs[0,0])
axs[0,4].sharey(axs[0,0])
axs[0,8].sharey(axs[0,6])
axs[0,10].sharey(axs[0,6])


axs[1,2].sharey(axs[1,0])
axs[1,4].sharey(axs[1,0])
axs[1,8].sharey(axs[1,6])
axs[1,10].sharey(axs[1,6])

axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)
axs[0,7].set_visible(False)
axs[0,9].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)
axs[1,7].set_visible(False)
axs[1,9].set_visible(False)

#f.suptitle("WEIGHTS", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_weight_1_sim_nyc_bike_MoGAN, exp_weight_2_sim_nyc_bike_MoGAN, exp_weight_3_sim_nyc_bike_MoGAN, axs[0,0], "JS weights", "weight", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_weight_1_sim_nyc_bike_gravity, exp_weight_2_sim_nyc_bike_gravity, exp_weight_3_sim_nyc_bike_gravity, axs[0,2], "JS weights", "weight")
js_nyc_bike_r = plot_JS_hist(exp_weight_1_sim_nyc_bike, exp_weight_2_sim_nyc_bike, exp_weight_3_sim_nyc_bike, axs[0,4], "JS weights", "weight")

js_nyc_taxi_c = plot_JS_hist(exp_weight_1_sim_nyc_taxi_MoGAN, exp_weight_2_sim_nyc_taxi_MoGAN, exp_weight_3_sim_nyc_taxi_MoGAN, axs[0,6], "JS weights", "weight", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_weight_1_sim_nyc_taxi_gravity, exp_weight_2_sim_nyc_taxi_gravity, exp_weight_3_sim_nyc_taxi_gravity, axs[0,8], "JS weights", "weight")
js_nyc_taxi_r = plot_JS_hist(exp_weight_1_sim_nyc_taxi, exp_weight_2_sim_nyc_taxi, exp_weight_3_sim_nyc_taxi, axs[0,10], "JS weights", "weight")


js_chi_bike_c = plot_JS_hist(exp_weight_1_sim_chi_bike_MoGAN, exp_weight_2_sim_chi_bike_MoGAN, exp_weight_3_sim_chi_bike_MoGAN, axs[1,0], "JS weights", "weight", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_weight_1_sim_chi_bike_gravity, exp_weight_2_sim_chi_bike_gravity, exp_weight_3_sim_chi_bike_gravity, axs[1,2], "JS weights", "weight")
js_chi_bike_r = plot_JS_hist(exp_weight_1_sim_chi_bike, exp_weight_2_sim_chi_bike, exp_weight_3_sim_chi_bike, axs[1,4], "JS weights", "weight")

js_chi_taxi_c = plot_JS_hist(exp_weight_1_sim_chi_taxi_MoGAN, exp_weight_2_sim_chi_taxi_MoGAN, exp_weight_3_sim_chi_taxi_MoGAN, axs[1,6], "JS weights", "weight", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_weight_1_sim_chi_taxi_gravity, exp_weight_2_sim_chi_taxi_gravity, exp_weight_3_sim_chi_taxi_gravity, axs[1,8], "JS weights", "weight")
js_chi_taxi_r = plot_JS_hist(exp_weight_1_sim_chi_taxi, exp_weight_2_sim_chi_taxi, exp_weight_3_sim_chi_taxi, axs[1,10], "JS weights", "weight")


#handles, labels = axs[0,0].get_legend_handles_labels()
#f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("Radiation\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,8].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,10].set_title("Radiation\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.8, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(1.8, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.8, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(1.8, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")

for i, ax in enumerate(f.axes):
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    
handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
    
#plt.tight_layout()
plt.savefig("Weights.pdf", bbox_inches='tight')

# %% [markdown]
# ## WeightsDistances ##

# %%
f, axs = plt.subplots(2, 11, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,0.01,22,   8,  22,0.01,22, 0.01, 22], hspace=0.4, wspace = 0.2))

axs[0,2].sharey(axs[0,0])
axs[0,4].sharey(axs[0,0])
axs[0,8].sharey(axs[0,6])
axs[0,10].sharey(axs[0,6])


axs[1,2].sharey(axs[1,0])
axs[1,4].sharey(axs[1,0])
axs[1,8].sharey(axs[1,6])
axs[1,10].sharey(axs[1,6])

axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)
axs[0,7].set_visible(False)
axs[0,9].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)
axs[1,7].set_visible(False)
axs[1,9].set_visible(False)


#f.suptitle("WEIGHT-DISTANCES", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_weight_dist_1_sim_nyc_bike_MoGAN, exp_weight_dist_2_sim_nyc_bike_MoGAN, exp_weight_dist_3_sim_nyc_bike_MoGAN, axs[0,0], "JS weight-dist.", "weight-dist", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_weight_dist_1_sim_nyc_bike_gravity, exp_weight_dist_2_sim_nyc_bike_gravity, exp_weight_dist_3_sim_nyc_bike_gravity, axs[0,2], "JS weight-dist.", "weight-dist")
js_nyc_bike_r = plot_JS_hist(exp_weight_dist_1_sim_nyc_bike, exp_weight_dist_2_sim_nyc_bike, exp_weight_dist_3_sim_nyc_bike, axs[0,4], "JS weight-dist.", "weight-dist")

js_nyc_taxi_c = plot_JS_hist(exp_weight_dist_1_sim_nyc_taxi_MoGAN, exp_weight_dist_2_sim_nyc_taxi_MoGAN, exp_weight_dist_3_sim_nyc_taxi_MoGAN, axs[0,6], "JS weight-dist.", "weight-dist", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_weight_dist_1_sim_nyc_taxi_gravity, exp_weight_dist_2_sim_nyc_taxi_gravity, exp_weight_dist_3_sim_nyc_taxi_gravity, axs[0,8], "JS weight-dist.", "weight-dist")
js_nyc_taxi_r = plot_JS_hist(exp_weight_dist_1_sim_nyc_taxi, exp_weight_dist_2_sim_nyc_taxi, exp_weight_dist_3_sim_nyc_taxi, axs[0,10], "JS weight-dist.", "weight-dist")



js_chi_bike_c = plot_JS_hist(exp_weight_dist_1_sim_chi_bike_MoGAN, exp_weight_dist_2_sim_chi_bike_MoGAN, exp_weight_dist_3_sim_chi_bike_MoGAN, axs[1,0], "JS weight-dist.", "weight-dist", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_weight_dist_1_sim_chi_bike_gravity, exp_weight_dist_2_sim_chi_bike_gravity, exp_weight_dist_3_sim_chi_bike_gravity, axs[1,2], "JS weight-dist.", "weight-dist")
js_chi_bike_r = plot_JS_hist(exp_weight_dist_1_sim_chi_bike, exp_weight_dist_2_sim_chi_bike, exp_weight_dist_3_sim_chi_bike, axs[1,4], "JS weight-dist.", "weight-dist")

js_chi_taxi_c = plot_JS_hist(exp_weight_dist_1_sim_chi_taxi_MoGAN, exp_weight_dist_2_sim_chi_taxi_MoGAN, exp_weight_dist_3_sim_chi_taxi_MoGAN, axs[1,6], "JS weight-dist.", "weight-dist", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_weight_dist_1_sim_chi_taxi_gravity, exp_weight_dist_2_sim_chi_taxi_gravity, exp_weight_dist_3_sim_chi_taxi_gravity, axs[1,8], "JS weight-dist.", "weight-dist")
js_chi_taxi_r = plot_JS_hist(exp_weight_dist_1_sim_chi_taxi, exp_weight_dist_2_sim_chi_taxi, exp_weight_dist_3_sim_chi_taxi, axs[1,10], "JS weight-dist.", "weight-dist")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("Radiation\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,8].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,10].set_title("Radiation\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.8, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(1.8, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.8, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(1.8, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")

for i, ax in enumerate(f.axes):
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))

#plt.tight_layout()
plt.savefig("WeightDistances.pdf", bbox_inches='tight')

# %% [markdown]
# ## Other Measures ##

# %%
f, axs = plt.subplots(2, 11, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,0.01,22,   8,  22,0.01,22, 0.01, 22], hspace=0.4, wspace = 0.2))


axs[0,2].sharey(axs[0,0])
axs[0,4].sharey(axs[0,0])
axs[0,8].sharey(axs[0,6])
axs[0,10].sharey(axs[0,6])


axs[1,2].sharey(axs[1,0])
axs[1,4].sharey(axs[1,0])
axs[1,8].sharey(axs[1,6])
axs[1,10].sharey(axs[1,6])


axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)
axs[0,7].set_visible(False)
axs[0,9].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)
axs[1,7].set_visible(False)
axs[1,9].set_visible(False)


#f.suptitle("Cut Distance", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_cutnorm_1_sim_nyc_bike_MoGAN, exp_cutnorm_2_sim_nyc_bike_MoGAN, exp_cutnorm_3_sim_nyc_bike_MoGAN, axs[0,0], "Cut Distance", "Cut Distance", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_cutnorm_1_sim_nyc_bike_gravity, exp_cutnorm_2_sim_nyc_bike_gravity, exp_cutnorm_3_sim_nyc_bike_gravity, axs[0,2], "Cut Distance", "Cut Distance")
js_nyc_bike_r = plot_JS_hist(exp_cutnorm_1_sim_nyc_bike, exp_cutnorm_2_sim_nyc_bike, exp_cutnorm_3_sim_nyc_bike, axs[0,4], "Cut Distance", "Cut Distance")

js_nyc_taxi_c = plot_JS_hist(exp_cutnorm_1_sim_nyc_taxi_MoGAN, exp_cutnorm_2_sim_nyc_taxi_MoGAN, exp_cutnorm_3_sim_nyc_taxi_MoGAN, axs[0,6], "Cut Distance", "Cut Distance", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_cutnorm_1_sim_nyc_taxi_gravity, exp_cutnorm_2_sim_nyc_taxi_gravity, exp_cutnorm_3_sim_nyc_taxi_gravity, axs[0,8], "Cut Distance", "Cut Distance")
js_nyc_taxi_r = plot_JS_hist(exp_cutnorm_1_sim_nyc_taxi, exp_cutnorm_2_sim_nyc_taxi, exp_cutnorm_3_sim_nyc_taxi, axs[0,10], "Cut Distance", "Cut Distance")


js_chi_bike_c = plot_JS_hist(exp_cutnorm_1_sim_chi_bike_MoGAN, exp_cutnorm_2_sim_chi_bike_MoGAN, exp_cutnorm_3_sim_chi_bike_MoGAN, axs[1,0], "Cut Distance", "Cut Distance", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_cutnorm_1_sim_chi_bike_gravity, exp_cutnorm_2_sim_chi_bike_gravity, exp_cutnorm_3_sim_chi_bike_gravity, axs[1,2], "Cut Distance", "Cut Distance")
js_chi_bike_r = plot_JS_hist(exp_cutnorm_1_sim_chi_bike, exp_cutnorm_2_sim_chi_bike, exp_cutnorm_3_sim_chi_bike, axs[1,4], "Cut Distance", "Cut Distance")

js_chi_taxi_c = plot_JS_hist(exp_cutnorm_1_sim_chi_taxi_MoGAN, exp_cutnorm_2_sim_chi_taxi_MoGAN, exp_cutnorm_3_sim_chi_taxi_MoGAN, axs[1,6], "Cut Distance", "Cut Distance", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_cutnorm_1_sim_chi_taxi_gravity, exp_cutnorm_2_sim_chi_taxi_gravity, exp_cutnorm_3_sim_chi_taxi_gravity, axs[1,8], "Cut Distance", "Cut Distance")
js_chi_taxi_r = plot_JS_hist(exp_cutnorm_1_sim_chi_taxi, exp_cutnorm_2_sim_chi_taxi, exp_cutnorm_3_sim_chi_taxi, axs[1,10], "Cut Distance", "Cut Distance")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("Radiation\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,8].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,10].set_title("Radiation\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.8, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(1.8, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.8, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(1.8, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Cutnorm.pdf", bbox_inches='tight')

# %%
f, axs = plt.subplots(2, 11, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,0.01,22,   8,  22,0.01,22, 0.01, 22], hspace=0.4, wspace = 0.2))

axs[0,2].sharey(axs[0,0])
axs[0,4].sharey(axs[0,0])
axs[0,8].sharey(axs[0,6])
axs[0,10].sharey(axs[0,6])


axs[1,2].sharey(axs[1,0])
axs[1,4].sharey(axs[1,0])
axs[1,8].sharey(axs[1,6])
axs[1,10].sharey(axs[1,6])


axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)
axs[0,7].set_visible(False)
axs[0,9].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)
axs[1,7].set_visible(False)
axs[1,9].set_visible(False)


#f.suptitle("CPC", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_cpc_1_sim_nyc_bike_MoGAN, exp_cpc_2_sim_nyc_bike_MoGAN, exp_cpc_3_sim_nyc_bike_MoGAN, axs[0,0], "CPC", "CPC", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_cpc_1_sim_nyc_bike_gravity, exp_cpc_2_sim_nyc_bike_gravity, exp_cpc_3_sim_nyc_bike_gravity, axs[0,2], "CPC", "CPC")
js_nyc_bike_r = plot_JS_hist(exp_cpc_1_sim_nyc_bike, exp_cpc_2_sim_nyc_bike, exp_cpc_3_sim_nyc_bike, axs[0,4], "CPC", "CPC")

js_nyc_taxi_c = plot_JS_hist(exp_cpc_1_sim_nyc_taxi_MoGAN, exp_cpc_2_sim_nyc_taxi_MoGAN, exp_cpc_3_sim_nyc_taxi_MoGAN, axs[0,6], "CPC", "CPC", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_cpc_1_sim_nyc_taxi_gravity, exp_cpc_2_sim_nyc_taxi_gravity, exp_cpc_3_sim_nyc_taxi_gravity, axs[0,8], "CPC", "CPC")
js_nyc_taxi_r = plot_JS_hist(exp_cpc_1_sim_nyc_taxi, exp_cpc_2_sim_nyc_taxi, exp_cpc_3_sim_nyc_taxi, axs[0,10], "CPC", "CPC")


js_chi_bike_c = plot_JS_hist(exp_cpc_1_sim_chi_bike_MoGAN, exp_cpc_2_sim_chi_bike_MoGAN, exp_cpc_3_sim_chi_bike_MoGAN, axs[1,0], "CPC", "CPC", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_cpc_1_sim_chi_bike_gravity, exp_cpc_2_sim_chi_bike_gravity, exp_cpc_3_sim_chi_bike_gravity, axs[1,2], "CPC", "CPC")
js_chi_bike_r = plot_JS_hist(exp_cpc_1_sim_chi_bike, exp_cpc_2_sim_chi_bike, exp_cpc_3_sim_chi_bike, axs[1,4], "CPC", "CPC")

js_chi_taxi_c = plot_JS_hist(exp_cpc_1_sim_chi_taxi_MoGAN, exp_cpc_2_sim_chi_taxi_MoGAN, exp_cpc_3_sim_chi_taxi_MoGAN, axs[1,6], "CPC", "CPC", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_cpc_1_sim_chi_taxi_gravity, exp_cpc_2_sim_chi_taxi_gravity, exp_cpc_3_sim_chi_taxi_gravity, axs[1,8], "CPC", "CPC")
js_chi_taxi_r = plot_JS_hist(exp_cpc_1_sim_chi_taxi, exp_cpc_2_sim_chi_taxi, exp_cpc_3_sim_chi_taxi, axs[1,10], "CPC", "CPC")



handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("Radiation\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,8].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,10].set_title("Radiation\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.8, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(1.8, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.8, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(1.8, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")

for i, ax in enumerate(f.axes):
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.1f'))


#plt.tight_layout()
plt.savefig("CPC.pdf", bbox_inches='tight')

# %%
f, axs = plt.subplots(2, 11, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,0.01,22,   8,  22,0.01,22, 0.01, 22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,4].sharey(axs[0,0])
axs[0,8].sharey(axs[0,6])
axs[0,10].sharey(axs[0,6])


axs[1,2].sharey(axs[1,0])
axs[1,4].sharey(axs[1,0])
axs[1,8].sharey(axs[1,6])
axs[1,10].sharey(axs[1,6])
    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)
axs[0,7].set_visible(False)
axs[0,9].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)
axs[1,7].set_visible(False)
axs[1,9].set_visible(False)


#f.suptitle("RMSE", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_rmse_1_sim_nyc_bike_MoGAN, exp_rmse_2_sim_nyc_bike_MoGAN, exp_rmse_3_sim_nyc_bike_MoGAN, axs[0,0], "RMSE", "RMSE", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_rmse_1_sim_nyc_bike_gravity, exp_rmse_2_sim_nyc_bike_gravity, exp_rmse_3_sim_nyc_bike_gravity, axs[0,2], "RMSE", "RMSE")
js_nyc_bike_r = plot_JS_hist(exp_rmse_1_sim_nyc_bike, exp_rmse_2_sim_nyc_bike, exp_rmse_3_sim_nyc_bike, axs[0,4], "RMSE", "RMSE")

js_nyc_taxi_c = plot_JS_hist(exp_rmse_1_sim_nyc_taxi_MoGAN, exp_rmse_2_sim_nyc_taxi_MoGAN, exp_rmse_3_sim_nyc_taxi_MoGAN, axs[0,6], "RMSE", "RMSE", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_rmse_1_sim_nyc_taxi_gravity, exp_rmse_2_sim_nyc_taxi_gravity, exp_rmse_3_sim_nyc_taxi_gravity, axs[0,8], "RMSE", "RMSE")
js_nyc_taxi_r = plot_JS_hist(exp_rmse_1_sim_nyc_taxi, exp_rmse_2_sim_nyc_taxi, exp_rmse_3_sim_nyc_taxi, axs[0,10], "RMSE", "RMSE")


js_chi_bike_c = plot_JS_hist(exp_rmse_1_sim_chi_bike_MoGAN, exp_rmse_2_sim_chi_bike_MoGAN, exp_rmse_3_sim_chi_bike_MoGAN, axs[1,0], "RMSE", "RMSE", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_rmse_1_sim_chi_bike_gravity, exp_rmse_2_sim_chi_bike_gravity, exp_rmse_3_sim_chi_bike_gravity, axs[1,2], "RMSE", "RMSE")
js_chi_bike_r = plot_JS_hist(exp_rmse_1_sim_chi_bike, exp_rmse_2_sim_chi_bike, exp_rmse_3_sim_chi_bike, axs[1,4], "RMSE", "RMSE")

js_chi_taxi_c = plot_JS_hist(exp_rmse_1_sim_chi_taxi_MoGAN, exp_rmse_2_sim_chi_taxi_MoGAN, exp_rmse_3_sim_chi_taxi_MoGAN, axs[1,6], "RMSE", "RMSE", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_rmse_1_sim_chi_taxi_gravity, exp_rmse_2_sim_chi_taxi_gravity, exp_rmse_3_sim_chi_taxi_gravity, axs[1,8], "RMSE", "RMSE")
js_chi_taxi_r = plot_JS_hist(exp_rmse_1_sim_chi_taxi, exp_rmse_2_sim_chi_taxi, exp_rmse_3_sim_chi_taxi, axs[1,10], "RMSE", "RMSE")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("Radiation\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,8].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,10].set_title("Radiation\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.8, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(1.8, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.8, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(1.8, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("RMSE.pdf", bbox_inches='tight')

# %%
f, axs = plt.subplots(2, 11, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,0.01,22,   8,  22,0.01,22, 0.01, 22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,4].sharey(axs[0,0])
axs[0,8].sharey(axs[0,6])
axs[0,10].sharey(axs[0,6])


axs[1,2].sharey(axs[1,0])
axs[1,4].sharey(axs[1,0])
axs[1,8].sharey(axs[1,6])
axs[1,10].sharey(axs[1,6])
    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)
axs[0,7].set_visible(False)
axs[0,9].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)
axs[1,7].set_visible(False)
axs[1,9].set_visible(False)


#f.suptitle("kernel", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_kernel_1_sim_nyc_bike_MoGAN, exp_kernel_2_sim_nyc_bike_MoGAN, exp_kernel_3_sim_nyc_bike_MoGAN, axs[0,0], "kernel", "kernel", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_kernel_1_sim_nyc_bike_gravity, exp_kernel_2_sim_nyc_bike_gravity, exp_kernel_3_sim_nyc_bike_gravity, axs[0,2], "kernel", "kernel")
js_nyc_bike_r = plot_JS_hist(exp_kernel_1_sim_nyc_bike, exp_kernel_2_sim_nyc_bike, exp_kernel_3_sim_nyc_bike, axs[0,4], "kernel", "kernel")

js_nyc_taxi_c = plot_JS_hist(exp_kernel_1_sim_nyc_taxi_MoGAN, exp_kernel_2_sim_nyc_taxi_MoGAN, exp_kernel_3_sim_nyc_taxi_MoGAN, axs[0,6], "kernel", "kernel", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_kernel_1_sim_nyc_taxi_gravity, exp_kernel_2_sim_nyc_taxi_gravity, exp_kernel_3_sim_nyc_taxi_gravity, axs[0,8], "kernel", "kernel")
js_nyc_taxi_r = plot_JS_hist(exp_kernel_1_sim_nyc_taxi, exp_kernel_2_sim_nyc_taxi, exp_kernel_3_sim_nyc_taxi, axs[0,10], "kernel", "kernel")


js_chi_bike_c = plot_JS_hist(exp_kernel_1_sim_chi_bike_MoGAN, exp_kernel_2_sim_chi_bike_MoGAN, exp_kernel_3_sim_chi_bike_MoGAN, axs[1,0], "kernel", "kernel", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_kernel_1_sim_chi_bike_gravity, exp_kernel_2_sim_chi_bike_gravity, exp_kernel_3_sim_chi_bike_gravity, axs[1,2], "kernel", "kernel")
js_chi_bike_r = plot_JS_hist(exp_kernel_1_sim_chi_bike, exp_kernel_2_sim_chi_bike, exp_kernel_3_sim_chi_bike, axs[1,4], "kernel", "kernel")

js_chi_taxi_c = plot_JS_hist(exp_kernel_1_sim_chi_taxi_MoGAN, exp_kernel_2_sim_chi_taxi_MoGAN, exp_kernel_3_sim_chi_taxi_MoGAN, axs[1,6], "kernel", "kernel", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_kernel_1_sim_chi_taxi_gravity, exp_kernel_2_sim_chi_taxi_gravity, exp_kernel_3_sim_chi_taxi_gravity, axs[1,8], "kernel", "kernel")
js_chi_taxi_r = plot_JS_hist(exp_kernel_1_sim_chi_taxi, exp_kernel_2_sim_chi_taxi, exp_kernel_3_sim_chi_taxi, axs[1,10], "kernel", "kernel")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("Radiation\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,8].set_title("Gravity\n\n", fontsize=42, y=0.91)
axs[0,10].set_title("Radiation\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.8, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(1.8, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.8, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(1.8, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("kernel.pdf", bbox_inches='tight')
