# %%
import numpy as np
import math
import pandas as pd
import itertools
from random import sample
import pickle
from scipy.spatial import distance

import seaborn as sns

# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import FormatStrFormatter
from matplotlib.offsetbox import AnchoredText
plt.rcParams["figure.figsize"] = (18, 15) # (w, h)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Random_Weighted #

# %%
with open("../BikeNYC/experiments/weight/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/weight/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/weight/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/weight/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/weight/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/weight/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
        
with open("../BikeCHI/experiments/weight/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/weight/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/weight/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/weight/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/weight/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/weight/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_taxi_random_weight = pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############
    
with open("../BikeNYC/experiments/weightdist/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/weightdist/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/weightdist/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/weightdist/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/weightdist/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/weightdist/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/weightdist/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/weightdist/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/weightdist/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/weightdist/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/weightdist/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/weightdist/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_taxi_random_weight = pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############    

with open("../BikeNYC/experiments/cutnorm/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/cutnorm/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/cutnorm/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/cutnorm/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/cutnorm/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/cutnorm/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/cutnorm/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/cutnorm/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/cutnorm/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/cutnorm/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/cutnorm/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/cutnorm/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("../BikeNYC/experiments/cpc/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/cpc/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/cpc/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/cpc/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/cpc/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/cpc/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/cpc/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/cpc/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/cpc/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/cpc/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/cpc/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/cpc/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("../BikeNYC/experiments/rmse/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/rmse/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/rmse/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/rmse/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/rmse/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/rmse/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/rmse/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/rmse/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/rmse/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/rmse/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/rmse/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/rmse/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("../BikeNYC/experiments/kernel/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/kernel/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/kernel/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/kernel/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/kernel/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/kernel/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/kernel/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/kernel/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/kernel/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/kernel/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/kernel/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/kernel/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("../BikeNYC/experiments/topo/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_topo_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/topo/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_topo_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/topo/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_topo_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/topo/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_topo_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/topo/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_topo_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/topo/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_topo_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/topo/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_topo_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/topo/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_topo_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/topo/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_topo_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/topo/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_topo_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/topo/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_topo_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/topo/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_topo_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("../BikeNYC/experiments/topo_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/topo_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/topo_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/topo_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/topo_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/topo_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/topo_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/topo_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/topo_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/topo_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/topo_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/topo_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("../BikeNYC/experiments/degree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_degree_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/degree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_degree_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/degree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_degree_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/degree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_degree_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/degree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_degree_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/degree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_degree_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/degree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_degree_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/degree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_degree_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/degree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_degree_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/degree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_degree_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/degree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_degree_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/degree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_degree_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("../BikeNYC/experiments/degree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/degree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/degree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/degree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/degree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/degree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/degree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/degree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/degree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/degree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/degree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/degree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("../BikeNYC/experiments/indegree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/indegree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/indegree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/indegree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/indegree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/indegree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/indegree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/indegree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/indegree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/indegree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/indegree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/indegree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("../BikeNYC/experiments/indegree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/indegree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/indegree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/indegree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/indegree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/indegree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/indegree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/indegree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/indegree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/indegree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/indegree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/indegree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############

with open("../BikeNYC/experiments/outdegree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/outdegree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/outdegree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/outdegree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/outdegree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/outdegree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/outdegree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/outdegree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/outdegree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/outdegree/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/outdegree/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/outdegree/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############  

with open("../BikeNYC/experiments/outdegree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/outdegree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/outdegree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/outdegree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/outdegree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/outdegree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/outdegree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/outdegree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/outdegree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/outdegree_unweighted/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/outdegree_unweighted/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/outdegree_unweighted/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############

with open("../BikeNYC/experiments/closeness/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_closeness_1_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/closeness/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_closeness_2_sim_nyc_bike_random_weight = pickle.load(fp)
with open("../BikeNYC/experiments/closeness/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_closeness_3_sim_nyc_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/closeness/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_closeness_1_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/closeness/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_closeness_2_sim_nyc_taxi_random_weight = pickle.load(fp)
with open("../TaxiNYC/experiments/closeness/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_closeness_3_sim_nyc_taxi_random_weight = pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/closeness/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_closeness_1_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/closeness/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_closeness_2_sim_chi_bike_random_weight = pickle.load(fp)
with open("../BikeCHI/experiments/closeness/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_closeness_3_sim_chi_bike_random_weight = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/closeness/Random_Weighted/1.txt", "rb") as fp:   # Unpickling
    exp_closeness_1_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/closeness/Random_Weighted/2.txt", "rb") as fp:   # Unpickling
    exp_closeness_2_sim_chi_taxi_random_weight = pickle.load(fp)
with open("../TaxiCHI/experiments/closeness/Random_Weighted/3.txt", "rb") as fp:   # Unpickling
    exp_closeness_3_sim_chi_taxi_random_weight = pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############

# %% [markdown]
# # MoGAN #

# %%
with open("../BikeNYC/experiments/weight/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/weight/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/weight/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/weight/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/weight/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/weight/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/weight/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/weight/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/weight/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/weight/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/weight/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/weight/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_3_sim_chi_taxi_MoGAN= pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############
    
with open("../BikeNYC/experiments/weightdist/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/weightdist/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/weightdist/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/weightdist/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/weightdist/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/weightdist/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/weightdist/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/weightdist/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/weightdist/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/weightdist/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/weightdist/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/weightdist/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_weight_dist_3_sim_chi_taxi_MoGAN= pickle.load(fp) 
    
######--------------------------------###############
######--------------------------------###############
######--------------------------------###############    

with open("../BikeNYC/experiments/cutnorm/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/cutnorm/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/cutnorm/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/cutnorm/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/cutnorm/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/cutnorm/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/cutnorm/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/cutnorm/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/cutnorm/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/cutnorm/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/cutnorm/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/cutnorm/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cutnorm_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("../BikeNYC/experiments/cpc/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/cpc/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/cpc/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/cpc/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/cpc/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/cpc/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/cpc/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/cpc/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/cpc/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/cpc/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_cpc_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/cpc/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_cpc_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/cpc/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_cpc_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 
    
with open("../BikeNYC/experiments/rmse/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/rmse/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/rmse/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/rmse/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/rmse/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/rmse/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/rmse/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/rmse/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/rmse/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/rmse/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_rmse_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/rmse/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_rmse_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/rmse/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_rmse_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############    

with open("../BikeNYC/experiments/kernel/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/kernel/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/kernel/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/kernel/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/kernel/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/kernel/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/kernel/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/kernel/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/kernel/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/kernel/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_kernel_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/kernel/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_kernel_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/kernel/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_kernel_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############   

with open("../BikeNYC/experiments/topo/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_topo_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/topo/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_topo_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/topo/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_topo_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/topo/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_topo_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/topo/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_topo_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/topo/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_topo_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/topo/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_topo_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/topo/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_topo_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/topo/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_topo_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/topo/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_topo_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/topo/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_topo_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/topo/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_topo_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 

with open("../BikeNYC/experiments/topo_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/topo_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/topo_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/topo_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/topo_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/topo_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/topo_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/topo_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/topo_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/topo_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/topo_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/topo_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_topo_unweighted_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 

with open("../BikeNYC/experiments/degree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_degree_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/degree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_degree_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/degree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_degree_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/degree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_degree_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/degree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_degree_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/degree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_degree_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/degree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_degree_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/degree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_degree_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/degree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_degree_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/degree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_degree_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/degree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_degree_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/degree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_degree_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 

with open("../BikeNYC/experiments/degree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/degree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/degree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/degree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/degree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/degree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/degree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/degree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/degree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/degree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/degree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/degree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_degree_unweighted_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 

with open("../BikeNYC/experiments/indegree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/indegree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/indegree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/indegree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/indegree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/indegree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/indegree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/indegree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/indegree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/indegree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/indegree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/indegree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 

with open("../BikeNYC/experiments/indegree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/indegree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/indegree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/indegree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/indegree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/indegree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/indegree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/indegree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/indegree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/indegree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/indegree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/indegree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_indegree_unweighted_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 

with open("../BikeNYC/experiments/outdegree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/outdegree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/outdegree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/outdegree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/outdegree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/outdegree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/outdegree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/outdegree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/outdegree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/outdegree/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/outdegree/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/outdegree/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------############### 

with open("../BikeNYC/experiments/outdegree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/outdegree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/outdegree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/outdegree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/outdegree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/outdegree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/outdegree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/outdegree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/outdegree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/outdegree_unweighted/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/outdegree_unweighted/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/outdegree_unweighted/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_outdegree_unweighted_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############

with open("../BikeNYC/experiments/closeness/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_closeness_1_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/closeness/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_closeness_2_sim_nyc_bike_MoGAN = pickle.load(fp)
with open("../BikeNYC/experiments/closeness/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_closeness_3_sim_nyc_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiNYC/experiments/closeness/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_closeness_1_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/closeness/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_closeness_2_sim_nyc_taxi_MoGAN= pickle.load(fp)
with open("../TaxiNYC/experiments/closeness/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_closeness_3_sim_nyc_taxi_MoGAN= pickle.load(fp)   
    
    
with open("../BikeCHI/experiments/closeness/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_closeness_1_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/closeness/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_closeness_2_sim_chi_bike_MoGAN = pickle.load(fp)
with open("../BikeCHI/experiments/closeness/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_closeness_3_sim_chi_bike_MoGAN = pickle.load(fp)    
    
with open("../TaxiCHI/experiments/closeness/MoGAN/1.txt", "rb") as fp:   # Unpickling
    exp_closeness_1_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/closeness/MoGAN/2.txt", "rb") as fp:   # Unpickling
    exp_closeness_2_sim_chi_taxi_MoGAN= pickle.load(fp)
with open("../TaxiCHI/experiments/closeness/MoGAN/3.txt", "rb") as fp:   # Unpickling
    exp_closeness_3_sim_chi_taxi_MoGAN= pickle.load(fp) 

######--------------------------------###############
######--------------------------------###############
######--------------------------------###############

# %%
def plot_JS_hist(exp1, exp2, exp3, ax, measure, metric, ylabel = False):   
    
    if isinstance(exp1, np.ndarray):
        exp1 =  exp1.tolist()
    if isinstance(exp2, np.ndarray):
        exp2 =  exp2.tolist()
    
    kwargs = dict(histtype='stepfilled', ec="k",  facecolor='none', density = True)
    
    min_v = min (exp1+exp2+exp3)
    max_v = max (exp1+exp2+exp3)
    
    r = np.linspace(min_v,max_v,20)
    k, bins = np.histogram(r,20)
    
    #bins = 20
    sns.kdeplot(exp1, label = "Test", bw_method=0.5, ax=ax, color = "red",   linewidth=1)
    sns.kdeplot(exp2, label = "Synthetic", bw_method=0.5, ax=ax, color = "blue",  linewidth=1)
    sns.kdeplot(exp3, label = "Mixed", bw_method=0.5, ax=ax, color = "green", linewidth=3)
    
    #INTER-DISTRIBUTION js
    values_3, base_3 = np.histogram(exp3, bins=bins, density=1)
    values_1, base_1 = np.histogram(exp1, bins=bins, density=1)
    js1 = distance.jensenshannon(np.asarray(values_3), np.asarray(values_1), np.e)
    
    values_2, base_2 = np.histogram(exp2, bins=bins, density=1)
    js2 = distance.jensenshannon(np.asarray(values_2), np.asarray(values_1), np.e)

    #text1 = str("JS(m,t)=%.2f" % js1)
    #text2 = str("JS(s,t)=%.2f" % js2)
    #text = text1 + '\n' + text2
    
    #ax.annotate(text, xy=(0.451, 0.99), xycoords='axes fraction', fontsize = 32, style = 'italic')    
    
    ax.tick_params(labelsize=34)
    ax.set_xlabel(measure, fontsize = 34)
    
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    if ylabel:
        ax.set_ylabel("density", fontsize = 34)
    else:
        ax.set_ylabel("", fontsize = 34)

    
    return (js1, js2)
    #ax.legend( prop={'size': 18})

# %% [markdown]
# ## Weights ##

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))

axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)

#f.suptitle("WEIGHTS", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_weight_1_sim_nyc_bike_MoGAN, exp_weight_2_sim_nyc_bike_MoGAN, exp_weight_3_sim_nyc_bike_MoGAN, axs[0,0], "JS weights", "weight", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_weight_1_sim_nyc_bike_random_weight, exp_weight_2_sim_nyc_bike_random_weight, exp_weight_3_sim_nyc_bike_random_weight, axs[0,2], "JS weights", "weight")

js_nyc_taxi_c = plot_JS_hist(exp_weight_1_sim_nyc_taxi_MoGAN, exp_weight_2_sim_nyc_taxi_MoGAN, exp_weight_3_sim_nyc_taxi_MoGAN, axs[0,4], "JS weights", "weight", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_weight_1_sim_nyc_taxi_random_weight, exp_weight_2_sim_nyc_taxi_random_weight, exp_weight_3_sim_nyc_taxi_random_weight, axs[0,6], "JS weights", "weight")


js_chi_bike_c = plot_JS_hist(exp_weight_1_sim_chi_bike_MoGAN, exp_weight_2_sim_chi_bike_MoGAN, exp_weight_3_sim_chi_bike_MoGAN, axs[1,0], "JS weights", "weight", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_weight_1_sim_chi_bike_random_weight, exp_weight_2_sim_chi_bike_random_weight, exp_weight_3_sim_chi_bike_random_weight, axs[1,2], "JS weights", "weight")

js_chi_taxi_c = plot_JS_hist(exp_weight_1_sim_chi_taxi_MoGAN, exp_weight_2_sim_chi_taxi_MoGAN, exp_weight_3_sim_chi_taxi_MoGAN, axs[1,4], "JS weights", "weight", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_weight_1_sim_chi_taxi_random_weight, exp_weight_2_sim_chi_taxi_random_weight, exp_weight_3_sim_chi_taxi_random_weight, axs[1,6], "JS weights", "weight")


#handles, labels = axs[0,0].get_legend_handles_labels()
#f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weighted\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weighted\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(1.2, -0.28, 'b) NYC taxi',  transform=axs[0,4].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(1.2, -0.28, 'd) CHI taxi',  transform=axs[1,4].transAxes,  fontsize = 30, weight="bold", ha="center")

for i, ax in enumerate(f.axes):
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    
handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
    
#plt.tight_layout()
plt.savefig("Ran_Weights.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'

df_concat.to_csv("tables/ran_weights.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.18    0.11       0.25        0.48    28%    77%
# NYCTaxi    0.06    0.08       0.11        0.28    47%    72%
# CHIBike    0.06    0.12       0.22        0.57    72%    80%
# CHITaxi    0.12    0.05       0.15        0.34    22%    85%

# %% [markdown]
# ## WeightsDistances ##

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))

axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])


axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)


axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("WEIGHT-DISTANCES", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_weight_dist_1_sim_nyc_bike_MoGAN, exp_weight_dist_2_sim_nyc_bike_MoGAN, exp_weight_dist_3_sim_nyc_bike_MoGAN, axs[0,0], "JS weight-dist.", "weight-dist", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_weight_dist_1_sim_nyc_bike_random_weight, exp_weight_dist_2_sim_nyc_bike_random_weight, exp_weight_dist_3_sim_nyc_bike_random_weight, axs[0,2], "JS weight-dist.", "weight-dist")

js_nyc_taxi_c = plot_JS_hist(exp_weight_dist_1_sim_nyc_taxi_MoGAN, exp_weight_dist_2_sim_nyc_taxi_MoGAN, exp_weight_dist_3_sim_nyc_taxi_MoGAN, axs[0,4], "JS weight-dist.", "weight-dist", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_weight_dist_1_sim_nyc_taxi_random_weight, exp_weight_dist_2_sim_nyc_taxi_random_weight, exp_weight_dist_3_sim_nyc_taxi_random_weight, axs[0,6], "JS weight-dist.", "weight-dist")



js_chi_bike_c = plot_JS_hist(exp_weight_dist_1_sim_chi_bike_MoGAN, exp_weight_dist_2_sim_chi_bike_MoGAN, exp_weight_dist_3_sim_chi_bike_MoGAN, axs[1,0], "JS weight-dist.", "weight-dist", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_weight_dist_1_sim_chi_bike_random_weight, exp_weight_dist_2_sim_chi_bike_random_weight, exp_weight_dist_3_sim_chi_bike_random_weight, axs[1,2], "JS weight-dist.", "weight-dist")

js_chi_taxi_c = plot_JS_hist(exp_weight_dist_1_sim_chi_taxi_MoGAN, exp_weight_dist_2_sim_chi_taxi_MoGAN, exp_weight_dist_3_sim_chi_taxi_MoGAN, axs[1,4], "JS weight-dist.", "weight-dist", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_weight_dist_1_sim_chi_taxi_random_weight, exp_weight_dist_2_sim_chi_taxi_random_weight, exp_weight_dist_3_sim_chi_taxi_random_weight, axs[1,6], "JS weight-dist.", "weight-dist")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weighted\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weighted\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(1.2, -0.28, 'b) NYC taxi',  transform=axs[0,4].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(1.2, -0.28, 'd) CHI taxi',  transform=axs[1,4].transAxes,  fontsize = 30, weight="bold", ha="center")

for i, ax in enumerate(f.axes):
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))

#plt.tight_layout()
plt.savefig("Ran_WeightDistances.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]

df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'


df_concat.to_csv("tables/ran_weight_dist.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.06    0.08       0.26        0.44    76%    82%
# NYCTaxi    0.06    0.10       0.12        0.25    52%    60%
# CHIBike    0.07    0.11       0.24        0.55    70%    80%
# CHITaxi    0.05    0.07       0.15        0.29    64%    76%

# %% [markdown]
# ## Other Measures ##

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))


axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])



axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("Cut Distance", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_cutnorm_1_sim_nyc_bike_MoGAN, exp_cutnorm_2_sim_nyc_bike_MoGAN, exp_cutnorm_3_sim_nyc_bike_MoGAN, axs[0,0], "Cut Distance", "Cut Distance", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_cutnorm_1_sim_nyc_bike_random_weight, exp_cutnorm_2_sim_nyc_bike_random_weight, exp_cutnorm_3_sim_nyc_bike_random_weight, axs[0,2], "Cut Distance", "Cut Distance")

js_nyc_taxi_c = plot_JS_hist(exp_cutnorm_1_sim_nyc_taxi_MoGAN, exp_cutnorm_2_sim_nyc_taxi_MoGAN, exp_cutnorm_3_sim_nyc_taxi_MoGAN, axs[0,4], "Cut Distance", "Cut Distance", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_cutnorm_1_sim_nyc_taxi_random_weight, exp_cutnorm_2_sim_nyc_taxi_random_weight, exp_cutnorm_3_sim_nyc_taxi_random_weight, axs[0,6], "Cut Distance", "Cut Distance")


js_chi_bike_c = plot_JS_hist(exp_cutnorm_1_sim_chi_bike_MoGAN, exp_cutnorm_2_sim_chi_bike_MoGAN, exp_cutnorm_3_sim_chi_bike_MoGAN, axs[1,0], "Cut Distance", "Cut Distance", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_cutnorm_1_sim_chi_bike_random_weight, exp_cutnorm_2_sim_chi_bike_random_weight, exp_cutnorm_3_sim_chi_bike_random_weight, axs[1,2], "Cut Distance", "Cut Distance")

js_chi_taxi_c = plot_JS_hist(exp_cutnorm_1_sim_chi_taxi_MoGAN, exp_cutnorm_2_sim_chi_taxi_MoGAN, exp_cutnorm_3_sim_chi_taxi_MoGAN, axs[1,4], "Cut Distance", "Cut Distance", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_cutnorm_1_sim_chi_taxi_random_weight, exp_cutnorm_2_sim_chi_taxi_random_weight, exp_cutnorm_3_sim_chi_taxi_random_weight, axs[1,6], "Cut Distance", "Cut Distance")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random_Weighted\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random_Weighted\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,4].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,4].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_Cutnorm.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]

df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'

df_concat.to_csv("tables/ran_cut.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.05    0.04       0.26        0.67    82%    94%
# NYCTaxi    0.05    0.12       0.23        0.67    77%    82%
# CHIBike    0.06    0.09       0.26        0.67    78%    87%
# CHITaxi    0.03    0.03       0.23        0.59    87%    95%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))

axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])


axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)


axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("CPC", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_cpc_1_sim_nyc_bike_MoGAN, exp_cpc_2_sim_nyc_bike_MoGAN, exp_cpc_3_sim_nyc_bike_MoGAN, axs[0,0], "CPC", "CPC", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_cpc_1_sim_nyc_bike_random_weight, exp_cpc_2_sim_nyc_bike_random_weight, exp_cpc_3_sim_nyc_bike_random_weight, axs[0,2], "CPC", "CPC")

js_nyc_taxi_c = plot_JS_hist(exp_cpc_1_sim_nyc_taxi_MoGAN, exp_cpc_2_sim_nyc_taxi_MoGAN, exp_cpc_3_sim_nyc_taxi_MoGAN, axs[0,4], "CPC", "CPC", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_cpc_1_sim_nyc_taxi_random_weight, exp_cpc_2_sim_nyc_taxi_random_weight, exp_cpc_3_sim_nyc_taxi_random_weight, axs[0,6], "CPC", "CPC")


js_chi_bike_c = plot_JS_hist(exp_cpc_1_sim_chi_bike_MoGAN, exp_cpc_2_sim_chi_bike_MoGAN, exp_cpc_3_sim_chi_bike_MoGAN, axs[1,0], "CPC", "CPC", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_cpc_1_sim_chi_bike_random_weight, exp_cpc_2_sim_chi_bike_random_weight, exp_cpc_3_sim_chi_bike_random_weight, axs[1,2], "CPC", "CPC")

js_chi_taxi_c = plot_JS_hist(exp_cpc_1_sim_chi_taxi_MoGAN, exp_cpc_2_sim_chi_taxi_MoGAN, exp_cpc_3_sim_chi_taxi_MoGAN, axs[1,4], "CPC", "CPC", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_cpc_1_sim_chi_taxi_random_weight, exp_cpc_2_sim_chi_taxi_random_weight, exp_cpc_3_sim_chi_taxi_random_weight, axs[1,6], "CPC", "CPC")



handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weighted\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weighted\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,4].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,4].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")

for i, ax in enumerate(f.axes):
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.1f'))


#plt.tight_layout()
plt.savefig("Ran_CPC.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_cpc.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.06    0.08       0.45        0.63    86%    88%
# NYCTaxi    0.09    0.11       0.37        0.59    76%    82%
# CHIBike    0.14    0.16       0.40        0.56    64%    71%
# CHITaxi    0.08    0.09       0.37        0.55    79%    84%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,  8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)


#f.suptitle("RMSE", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_rmse_1_sim_nyc_bike_MoGAN, exp_rmse_2_sim_nyc_bike_MoGAN, exp_rmse_3_sim_nyc_bike_MoGAN, axs[0,0], "NRMSE", "NRMSE", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_rmse_1_sim_nyc_bike_random_weight, exp_rmse_2_sim_nyc_bike_random_weight, exp_rmse_3_sim_nyc_bike_random_weight, axs[0,2], "NRMSE", "NRMSE")

js_nyc_taxi_c = plot_JS_hist(exp_rmse_1_sim_nyc_taxi_MoGAN, exp_rmse_2_sim_nyc_taxi_MoGAN, exp_rmse_3_sim_nyc_taxi_MoGAN, axs[0,4], "NRMSE", "NRMSE", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_rmse_1_sim_nyc_taxi_random_weight, exp_rmse_2_sim_nyc_taxi_random_weight, exp_rmse_3_sim_nyc_taxi_random_weight, axs[0,6], "NRMSE", "NRMSE")


js_chi_bike_c = plot_JS_hist(exp_rmse_1_sim_chi_bike_MoGAN, exp_rmse_2_sim_chi_bike_MoGAN, exp_rmse_3_sim_chi_bike_MoGAN, axs[1,0], "NRMSE", "NRMSE", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_rmse_1_sim_chi_bike_random_weight, exp_rmse_2_sim_chi_bike_random_weight, exp_rmse_3_sim_chi_bike_random_weight, axs[1,2], "NRMSE", "NRMSE")

js_chi_taxi_c = plot_JS_hist(exp_rmse_1_sim_chi_taxi_MoGAN, exp_rmse_2_sim_chi_taxi_MoGAN, exp_rmse_3_sim_chi_taxi_MoGAN, axs[1,4], "NRMSE", "NRMSE", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_rmse_1_sim_chi_taxi_random_weight, exp_rmse_2_sim_chi_taxi_random_weight, exp_rmse_3_sim_chi_taxi_random_weight, axs[1,6], "NRMSE", "NRMSE")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.8, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.8, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_RMSE.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]



df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_rmse.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.04    0.05       0.35        0.42    88%    87%
# NYCTaxi    0.05    0.09       0.36        0.47    87%    80%
# CHIBike    0.06    0.07       0.33        0.40    83%    82%
# CHITaxi    0.05    0.06       0.36        0.43    87%    86%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("kernel", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_kernel_1_sim_nyc_bike_MoGAN, exp_kernel_2_sim_nyc_bike_MoGAN, exp_kernel_3_sim_nyc_bike_MoGAN, axs[0,0], "kernel", "kernel", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_kernel_1_sim_nyc_bike_random_weight, exp_kernel_2_sim_nyc_bike_random_weight, exp_kernel_3_sim_nyc_bike_random_weight, axs[0,2], "kernel", "kernel")

js_nyc_taxi_c = plot_JS_hist(exp_kernel_1_sim_nyc_taxi_MoGAN, exp_kernel_2_sim_nyc_taxi_MoGAN, exp_kernel_3_sim_nyc_taxi_MoGAN, axs[0,4], "kernel", "kernel", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_kernel_1_sim_nyc_taxi_random_weight, exp_kernel_2_sim_nyc_taxi_random_weight, exp_kernel_3_sim_nyc_taxi_random_weight, axs[0,6], "kernel", "kernel")


js_chi_bike_c = plot_JS_hist(exp_kernel_1_sim_chi_bike_MoGAN, exp_kernel_2_sim_chi_bike_MoGAN, exp_kernel_3_sim_chi_bike_MoGAN, axs[1,0], "kernel", "kernel", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_kernel_1_sim_chi_bike_random_weight, exp_kernel_2_sim_chi_bike_random_weight, exp_kernel_3_sim_chi_bike_random_weight, axs[1,2], "kernel", "kernel")

js_chi_taxi_c = plot_JS_hist(exp_kernel_1_sim_chi_taxi_MoGAN, exp_kernel_2_sim_chi_taxi_MoGAN, exp_kernel_3_sim_chi_taxi_MoGAN, axs[1,4], "kernel", "kernel", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_kernel_1_sim_chi_taxi_random_weight, exp_kernel_2_sim_chi_taxi_random_weight, exp_kernel_3_sim_chi_taxi_random_weight, axs[1,6], "kernel", "kernel")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_kernel.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_kernel.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1  delta2
# NYCBike    0.11    0.53       0.14        0.05    22%  -1011%
# NYCTaxi    0.13    0.64       0.13        0.19    -2%   -241%
# CHIBike    0.17    0.27       0.19        0.10    14%   -178%
# CHITaxi    0.21    0.43       0.34        0.06    38%   -602%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("topo", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_topo_1_sim_nyc_bike_MoGAN, exp_topo_2_sim_nyc_bike_MoGAN, exp_topo_3_sim_nyc_bike_MoGAN, axs[0,0], "topo", "topo", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_topo_1_sim_nyc_bike_random_weight, exp_topo_2_sim_nyc_bike_random_weight, exp_topo_3_sim_nyc_bike_random_weight, axs[0,2], "topo", "topo")

js_nyc_taxi_c = plot_JS_hist(exp_topo_1_sim_nyc_taxi_MoGAN, exp_topo_2_sim_nyc_taxi_MoGAN, exp_topo_3_sim_nyc_taxi_MoGAN, axs[0,4], "topo", "topo", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_topo_1_sim_nyc_taxi_random_weight, exp_topo_2_sim_nyc_taxi_random_weight, exp_topo_3_sim_nyc_taxi_random_weight, axs[0,6], "topo", "topo")


js_chi_bike_c = plot_JS_hist(exp_topo_1_sim_chi_bike_MoGAN, exp_topo_2_sim_chi_bike_MoGAN, exp_topo_3_sim_chi_bike_MoGAN, axs[1,0], "topo", "topo", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_topo_1_sim_chi_bike_random_weight, exp_topo_2_sim_chi_bike_random_weight, exp_topo_3_sim_chi_bike_random_weight, axs[1,2], "topo", "topo")

js_chi_taxi_c = plot_JS_hist(exp_topo_1_sim_chi_taxi_MoGAN, exp_topo_2_sim_chi_taxi_MoGAN, exp_topo_3_sim_chi_taxi_MoGAN, axs[1,4], "topo", "topo", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_topo_1_sim_chi_taxi_random_weight, exp_topo_2_sim_chi_taxi_random_weight, exp_topo_3_sim_chi_taxi_random_weight, axs[1,6], "topo", "topo")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_topo.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_topo.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.30    0.31       0.24        0.21   -27%   -47%
# NYCTaxi    0.22    0.19       0.13        0.26   -65%    28%
# CHIBike    0.14    0.11       0.15        0.20    11%    44%
# CHITaxi    0.21    0.24       0.11        0.28   -87%    14%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("topo_unweighted", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_topo_unweighted_1_sim_nyc_bike_MoGAN, exp_topo_unweighted_2_sim_nyc_bike_MoGAN, exp_topo_unweighted_3_sim_nyc_bike_MoGAN, axs[0,0], "topo_unweighted", "topo_unweighted", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_topo_unweighted_1_sim_nyc_bike_random_weight, exp_topo_unweighted_2_sim_nyc_bike_random_weight, exp_topo_unweighted_3_sim_nyc_bike_random_weight, axs[0,2], "topo_unweighted", "topo_unweighted")

js_nyc_taxi_c = plot_JS_hist(exp_topo_unweighted_1_sim_nyc_taxi_MoGAN, exp_topo_unweighted_2_sim_nyc_taxi_MoGAN, exp_topo_unweighted_3_sim_nyc_taxi_MoGAN, axs[0,4], "topo_unweighted", "topo_unweighted", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_topo_unweighted_1_sim_nyc_taxi_random_weight, exp_topo_unweighted_2_sim_nyc_taxi_random_weight, exp_topo_unweighted_3_sim_nyc_taxi_random_weight, axs[0,6], "topo_unweighted", "topo_unweighted")


js_chi_bike_c = plot_JS_hist(exp_topo_unweighted_1_sim_chi_bike_MoGAN, exp_topo_unweighted_2_sim_chi_bike_MoGAN, exp_topo_unweighted_3_sim_chi_bike_MoGAN, axs[1,0], "topo_unweighted", "topo_unweighted", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_topo_unweighted_1_sim_chi_bike_random_weight, exp_topo_unweighted_2_sim_chi_bike_random_weight, exp_topo_unweighted_3_sim_chi_bike_random_weight, axs[1,2], "topo_unweighted", "topo_unweighted")

js_chi_taxi_c = plot_JS_hist(exp_topo_unweighted_1_sim_chi_taxi_MoGAN, exp_topo_unweighted_2_sim_chi_taxi_MoGAN, exp_topo_unweighted_3_sim_chi_taxi_MoGAN, axs[1,4], "topo_unweighted", "topo_unweighted", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_topo_unweighted_1_sim_chi_taxi_random_weight, exp_topo_unweighted_2_sim_chi_taxi_random_weight, exp_topo_unweighted_3_sim_chi_taxi_random_weight, axs[1,6], "topo_unweighted", "topo_unweighted")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_topo_unweighted.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_topo_unweighted.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.74    0.75       0.17        0.19  -325%  -295%
# NYCTaxi    0.83    0.83       0.10        0.17  -760%  -377%
# CHIBike    0.40    0.36       0.20        0.45   -96%    19%
# CHITaxi    0.30    0.42       0.16        0.38   -89%   -10%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("degree", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_degree_1_sim_nyc_bike_MoGAN, exp_degree_2_sim_nyc_bike_MoGAN, exp_degree_3_sim_nyc_bike_MoGAN, axs[0,0], "degree", "degree", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_degree_1_sim_nyc_bike_random_weight, exp_degree_2_sim_nyc_bike_random_weight, exp_degree_3_sim_nyc_bike_random_weight, axs[0,2], "degree", "degree")

js_nyc_taxi_c = plot_JS_hist(exp_degree_1_sim_nyc_taxi_MoGAN, exp_degree_2_sim_nyc_taxi_MoGAN, exp_degree_3_sim_nyc_taxi_MoGAN, axs[0,4], "degree", "degree", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_degree_1_sim_nyc_taxi_random_weight, exp_degree_2_sim_nyc_taxi_random_weight, exp_degree_3_sim_nyc_taxi_random_weight, axs[0,6], "degree", "degree")


js_chi_bike_c = plot_JS_hist(exp_degree_1_sim_chi_bike_MoGAN, exp_degree_2_sim_chi_bike_MoGAN, exp_degree_3_sim_chi_bike_MoGAN, axs[1,0], "degree", "degree", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_degree_1_sim_chi_bike_random_weight, exp_degree_2_sim_chi_bike_random_weight, exp_degree_3_sim_chi_bike_random_weight, axs[1,2], "degree", "degree")

js_chi_taxi_c = plot_JS_hist(exp_degree_1_sim_chi_taxi_MoGAN, exp_degree_2_sim_chi_taxi_MoGAN, exp_degree_3_sim_chi_taxi_MoGAN, axs[1,4], "degree", "degree", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_degree_1_sim_chi_taxi_random_weight, exp_degree_2_sim_chi_taxi_random_weight, exp_degree_3_sim_chi_taxi_random_weight, axs[1,6], "degree", "degree")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_degree.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_degree.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.04    0.06       0.26        0.63    85%    90%
# NYCTaxi    0.05    0.10       0.22        0.66    78%    85%
# CHIBike    0.07    0.09       0.28        0.64    76%    86%
# CHITaxi    0.04    0.06       0.21        0.52    81%    89%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("outdegree", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_outdegree_1_sim_nyc_bike_MoGAN, exp_outdegree_2_sim_nyc_bike_MoGAN, exp_outdegree_3_sim_nyc_bike_MoGAN, axs[0,0], "outdegree", "outdegree", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_outdegree_1_sim_nyc_bike_random_weight, exp_outdegree_2_sim_nyc_bike_random_weight, exp_outdegree_3_sim_nyc_bike_random_weight, axs[0,2], "outdegree", "outdegree")

js_nyc_taxi_c = plot_JS_hist(exp_outdegree_1_sim_nyc_taxi_MoGAN, exp_outdegree_2_sim_nyc_taxi_MoGAN, exp_outdegree_3_sim_nyc_taxi_MoGAN, axs[0,4], "outdegree", "outdegree", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_outdegree_1_sim_nyc_taxi_random_weight, exp_outdegree_2_sim_nyc_taxi_random_weight, exp_outdegree_3_sim_nyc_taxi_random_weight, axs[0,6], "outdegree", "outdegree")


js_chi_bike_c = plot_JS_hist(exp_outdegree_1_sim_chi_bike_MoGAN, exp_outdegree_2_sim_chi_bike_MoGAN, exp_outdegree_3_sim_chi_bike_MoGAN, axs[1,0], "outdegree", "outdegree", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_outdegree_1_sim_chi_bike_random_weight, exp_outdegree_2_sim_chi_bike_random_weight, exp_outdegree_3_sim_chi_bike_random_weight, axs[1,2], "outdegree", "outdegree")

js_chi_taxi_c = plot_JS_hist(exp_outdegree_1_sim_chi_taxi_MoGAN, exp_outdegree_2_sim_chi_taxi_MoGAN, exp_outdegree_3_sim_chi_taxi_MoGAN, axs[1,4], "outdegree", "outdegree", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_outdegree_1_sim_chi_taxi_random_weight, exp_outdegree_2_sim_chi_taxi_random_weight, exp_outdegree_3_sim_chi_taxi_random_weight, axs[1,6], "outdegree", "outdegree")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_outdegree.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_outdegree.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.05    0.06       0.25        0.59    82%    89%
# NYCTaxi    0.04    0.11       0.22        0.64    80%    83%
# CHIBike    0.06    0.07       0.25        0.61    77%    89%
# CHITaxi    0.04    0.05       0.22        0.47    82%    89%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("outdegree_unweighted", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_outdegree_unweighted_1_sim_nyc_bike_MoGAN, exp_outdegree_unweighted_2_sim_nyc_bike_MoGAN, exp_outdegree_unweighted_3_sim_nyc_bike_MoGAN, axs[0,0], "outdegree_unweighted", "outdegree_unweighted", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_outdegree_unweighted_1_sim_nyc_bike_random_weight, exp_outdegree_unweighted_2_sim_nyc_bike_random_weight, exp_outdegree_unweighted_3_sim_nyc_bike_random_weight, axs[0,2], "outdegree_unweighted", "outdegree_unweighted")

js_nyc_taxi_c = plot_JS_hist(exp_outdegree_unweighted_1_sim_nyc_taxi_MoGAN, exp_outdegree_unweighted_2_sim_nyc_taxi_MoGAN, exp_outdegree_unweighted_3_sim_nyc_taxi_MoGAN, axs[0,4], "outdegree_unweighted", "outdegree_unweighted", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_outdegree_unweighted_1_sim_nyc_taxi_random_weight, exp_outdegree_unweighted_2_sim_nyc_taxi_random_weight, exp_outdegree_unweighted_3_sim_nyc_taxi_random_weight, axs[0,6], "outdegree_unweighted", "outdegree_unweighted")


js_chi_bike_c = plot_JS_hist(exp_outdegree_unweighted_1_sim_chi_bike_MoGAN, exp_outdegree_unweighted_2_sim_chi_bike_MoGAN, exp_outdegree_unweighted_3_sim_chi_bike_MoGAN, axs[1,0], "outdegree_unweighted", "outdegree_unweighted", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_outdegree_unweighted_1_sim_chi_bike_random_weight, exp_outdegree_unweighted_2_sim_chi_bike_random_weight, exp_outdegree_unweighted_3_sim_chi_bike_random_weight, axs[1,2], "outdegree_unweighted", "outdegree_unweighted")

js_chi_taxi_c = plot_JS_hist(exp_outdegree_unweighted_1_sim_chi_taxi_MoGAN, exp_outdegree_unweighted_2_sim_chi_taxi_MoGAN, exp_outdegree_unweighted_3_sim_chi_taxi_MoGAN, axs[1,4], "outdegree_unweighted", "outdegree_unweighted", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_outdegree_unweighted_1_sim_chi_taxi_random_weight, exp_outdegree_unweighted_2_sim_chi_taxi_random_weight, exp_outdegree_unweighted_3_sim_chi_taxi_random_weight, axs[1,6], "outdegree_unweighted", "outdegree_unweighted")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_outdegree_unweighted.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_outdegree_unweighted.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.31    0.28       0.22        0.53   -41%    47%
# NYCTaxi    0.69    0.52       0.19        0.40  -254%   -30%
# CHIBike    0.17    0.16       0.22        0.66    23%    76%
# CHITaxi    0.12    0.08       0.31        0.70    60%    88%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("indegree", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_indegree_1_sim_nyc_bike_MoGAN, exp_indegree_2_sim_nyc_bike_MoGAN, exp_indegree_3_sim_nyc_bike_MoGAN, axs[0,0], "indegree", "indegree", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_indegree_1_sim_nyc_bike_random_weight, exp_indegree_2_sim_nyc_bike_random_weight, exp_indegree_3_sim_nyc_bike_random_weight, axs[0,2], "indegree", "indegree")

js_nyc_taxi_c = plot_JS_hist(exp_indegree_1_sim_nyc_taxi_MoGAN, exp_indegree_2_sim_nyc_taxi_MoGAN, exp_indegree_3_sim_nyc_taxi_MoGAN, axs[0,4], "indegree", "indegree", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_indegree_1_sim_nyc_taxi_random_weight, exp_indegree_2_sim_nyc_taxi_random_weight, exp_indegree_3_sim_nyc_taxi_random_weight, axs[0,6], "indegree", "indegree")


js_chi_bike_c = plot_JS_hist(exp_indegree_1_sim_chi_bike_MoGAN, exp_indegree_2_sim_chi_bike_MoGAN, exp_indegree_3_sim_chi_bike_MoGAN, axs[1,0], "indegree", "indegree", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_indegree_1_sim_chi_bike_random_weight, exp_indegree_2_sim_chi_bike_random_weight, exp_indegree_3_sim_chi_bike_random_weight, axs[1,2], "indegree", "indegree")

js_chi_taxi_c = plot_JS_hist(exp_indegree_1_sim_chi_taxi_MoGAN, exp_indegree_2_sim_chi_taxi_MoGAN, exp_indegree_3_sim_chi_taxi_MoGAN, axs[1,4], "indegree", "indegree", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_indegree_1_sim_chi_taxi_random_weight, exp_indegree_2_sim_chi_taxi_random_weight, exp_indegree_3_sim_chi_taxi_random_weight, axs[1,6], "indegree", "indegree")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_indegree.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_indegree.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.04    0.06       0.25        0.59    84%    90%
# NYCTaxi    0.06    0.09       0.21        0.64    71%    85%
# CHIBike    0.07    0.09       0.28        0.62    74%    86%
# CHITaxi    0.04    0.05       0.19        0.47    82%    90%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("indegree_unweighted", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_indegree_unweighted_1_sim_nyc_bike_MoGAN, exp_indegree_unweighted_2_sim_nyc_bike_MoGAN, exp_indegree_unweighted_3_sim_nyc_bike_MoGAN, axs[0,0], "indegree_unweighted", "indegree_unweighted", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_indegree_unweighted_1_sim_nyc_bike_random_weight, exp_indegree_unweighted_2_sim_nyc_bike_random_weight, exp_indegree_unweighted_3_sim_nyc_bike_random_weight, axs[0,2], "indegree_unweighted", "indegree_unweighted")

js_nyc_taxi_c = plot_JS_hist(exp_indegree_unweighted_1_sim_nyc_taxi_MoGAN, exp_indegree_unweighted_2_sim_nyc_taxi_MoGAN, exp_indegree_unweighted_3_sim_nyc_taxi_MoGAN, axs[0,4], "indegree_unweighted", "indegree_unweighted", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_indegree_unweighted_1_sim_nyc_taxi_random_weight, exp_indegree_unweighted_2_sim_nyc_taxi_random_weight, exp_indegree_unweighted_3_sim_nyc_taxi_random_weight, axs[0,6], "indegree_unweighted", "indegree_unweighted")


js_chi_bike_c = plot_JS_hist(exp_indegree_unweighted_1_sim_chi_bike_MoGAN, exp_indegree_unweighted_2_sim_chi_bike_MoGAN, exp_indegree_unweighted_3_sim_chi_bike_MoGAN, axs[1,0], "indegree_unweighted", "indegree_unweighted", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_indegree_unweighted_1_sim_chi_bike_random_weight, exp_indegree_unweighted_2_sim_chi_bike_random_weight, exp_indegree_unweighted_3_sim_chi_bike_random_weight, axs[1,2], "indegree_unweighted", "indegree_unweighted")

js_chi_taxi_c = plot_JS_hist(exp_indegree_unweighted_1_sim_chi_taxi_MoGAN, exp_indegree_unweighted_2_sim_chi_taxi_MoGAN, exp_indegree_unweighted_3_sim_chi_taxi_MoGAN, axs[1,4], "indegree_unweighted", "indegree_unweighted", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_indegree_unweighted_1_sim_chi_taxi_random_weight, exp_indegree_unweighted_2_sim_chi_taxi_random_weight, exp_indegree_unweighted_3_sim_chi_taxi_random_weight, axs[1,6], "indegree_unweighted", "indegree_unweighted")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_indegree_unweighted.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_indegree_unweighted.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.29    0.27       0.22        0.50   -30%    45%
# NYCTaxi    0.68    0.55       0.19        0.38  -256%   -43%
# CHIBike    0.18    0.17       0.22        0.63    17%    74%
# CHITaxi    0.08    0.12       0.29        0.71    73%    84%

# %%
f, axs = plt.subplots(2, 7, figsize=(40,20), gridspec_kw=dict(width_ratios=[22,0.01,22,   8,  22,0.01,22], hspace=0.4, wspace = 0.2))
                      
axs[0,2].sharey(axs[0,0])
axs[0,6].sharey(axs[0,4])


axs[1,2].sharey(axs[1,0])
axs[1,6].sharey(axs[1,4])

    
axs[0,1].set_visible(False)
axs[0,3].set_visible(False)
axs[0,5].set_visible(False)

axs[1,1].set_visible(False)
axs[1,3].set_visible(False)
axs[1,5].set_visible(False)



#f.suptitle("closeness", fontsize=55, fontweight='bold', y=1.02)

js_nyc_bike_c = plot_JS_hist(exp_closeness_1_sim_nyc_bike_MoGAN, exp_closeness_2_sim_nyc_bike_MoGAN, exp_closeness_3_sim_nyc_bike_MoGAN, axs[0,0], "closeness", "closeness", ylabel = True)
js_nyc_bike_g = plot_JS_hist(exp_closeness_1_sim_nyc_bike_random_weight, exp_closeness_2_sim_nyc_bike_random_weight, exp_closeness_3_sim_nyc_bike_random_weight, axs[0,2], "closeness", "closeness")

js_nyc_taxi_c = plot_JS_hist(exp_closeness_1_sim_nyc_taxi_MoGAN, exp_closeness_2_sim_nyc_taxi_MoGAN, exp_closeness_3_sim_nyc_taxi_MoGAN, axs[0,4], "closeness", "closeness", ylabel = True)
js_nyc_taxi_g = plot_JS_hist(exp_closeness_1_sim_nyc_taxi_random_weight, exp_closeness_2_sim_nyc_taxi_random_weight, exp_closeness_3_sim_nyc_taxi_random_weight, axs[0,6], "closeness", "closeness")


js_chi_bike_c = plot_JS_hist(exp_closeness_1_sim_chi_bike_MoGAN, exp_closeness_2_sim_chi_bike_MoGAN, exp_closeness_3_sim_chi_bike_MoGAN, axs[1,0], "closeness", "closeness", ylabel = True)
js_chi_bike_g = plot_JS_hist(exp_closeness_1_sim_chi_bike_random_weight, exp_closeness_2_sim_chi_bike_random_weight, exp_closeness_3_sim_chi_bike_random_weight, axs[1,2], "closeness", "closeness")

js_chi_taxi_c = plot_JS_hist(exp_closeness_1_sim_chi_taxi_MoGAN, exp_closeness_2_sim_chi_taxi_MoGAN, exp_closeness_3_sim_chi_taxi_MoGAN, axs[1,4], "closeness", "closeness", ylabel = True)
js_chi_taxi_g = plot_JS_hist(exp_closeness_1_sim_chi_taxi_random_weight, exp_closeness_2_sim_chi_taxi_random_weight, exp_closeness_3_sim_chi_taxi_random_weight, axs[1,6], "closeness", "closeness")




handles, labels = axs[0,0].get_legend_handles_labels()
f.legend(handles, labels, prop={'size': 33}, bbox_to_anchor=(0.92, 1.01), ncol=3)
#plt.subplots_adjust( hspace = 0.7)

axs[0,0].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,2].set_title("Random Weight\n\n", fontsize=42, y=0.91)
axs[0,4].set_title("MoGAN\n\n", fontsize=42, y=0.91)
axs[0,6].set_title("Random Weight\n\n", fontsize=42, y=0.91)

axs[0,0].text(1.2, -0.28, 'a) NYC bike',  transform=axs[0,0].transAxes, fontsize = 30, weight="bold", ha="center")
axs[0,6].text(0, -0.28, 'b) NYC taxi',  transform=axs[0,6].transAxes, fontsize = 30, weight="bold", ha="center")
axs[1,0].text(1.2, -0.28, 'c) CHI bike',  transform=axs[1,0].transAxes,  fontsize = 30, weight="bold", ha="center")
axs[1,6].text(0, -0.28, 'd) CHI taxi',  transform=axs[1,6].transAxes,  fontsize = 30, weight="bold", ha="center")



#plt.tight_layout()
plt.savefig("Ran_closeness.pdf", bbox_inches='tight')

# %%
df_mogan = pd.DataFrame([js_nyc_bike_c, js_nyc_taxi_c, js_chi_bike_c, js_chi_taxi_c])
df_gravity = pd.DataFrame([js_nyc_bike_g, js_nyc_taxi_g, js_chi_bike_g, js_chi_taxi_g])
df_concat = pd.concat([df_mogan, df_gravity], axis=1)
df_concat.columns = ["MoGAN1", "MoGAN2",  "Random W1", "Random W 2"]


df_concat["delta1"] = -(df_concat["MoGAN1"] - df_concat["Random W1"])/ df_concat["Random W1"]
df_concat["delta2"] = -(df_concat["MoGAN2"] - df_concat["Random W 2"])/ df_concat["Random W 2"]


df_concat = df_concat.round(2)
df_concat = df_concat.rename(index={0: 'NYCBike', 1: 'NYCTaxi', 2:"CHIBike", 3: "CHITaxi"})


df_concat["delta1"] = (df_concat["delta1"]*100).astype(int).astype(str) + '%'
df_concat["delta2"] = (df_concat["delta2"]*100).astype(int).astype(str) + '%'



df_concat.to_csv("tables/ran_closeness.csv")

df_concat
# Out:
#          MoGAN1  MoGAN2  Random W1  Random W 2 delta1 delta2
# NYCBike    0.77    0.77       0.19        0.36  -315%  -113%
# NYCTaxi    0.83    0.83       0.13        0.32  -547%  -163%
# CHIBike    0.53    0.32       0.18        0.45  -198%    27%
# CHITaxi    0.45    0.47       0.09        0.40  -418%   -19%
